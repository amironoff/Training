# %%
# https://habrahabr.ru/company/ods/blog/322626/

# отключим предупреждения Anaconda
import warnings
warnings.simplefilter('ignore')

# импортируем Pandas и Numpy
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data/telecom-churn.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-28-eddfce50834d> in <module>()
# ----> 1 df = pd.read_csv("data/telecom-churn.csv")
#
# ...

# %%
pd.set_option('display.max_columns', None)  

df.head()
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>state</th>
#       <th>account length</th>
#       <th>area code</th>
#       <th>phone number</th>
#       <th>international plan</th>
#       <th>voice mail plan</th>
#       <th>number vmail messages</th>
#       <th>total day minutes</th>
#       <th>total day calls</th>
#       <th>total day charge</th>
#       <th>total eve minutes</th>
#       <th>total eve calls</th>
#       <th>total eve charge</th>
#       <th>total night minutes</th>
#       <th>total night calls</th>
#       <th>total night charge</th>
#       <th>total intl minutes</th>
#       <th>total intl calls</th>
#       <th>total intl charge</th>
#       <th>customer service calls</th>
#       <th>churn</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>KS</td>
#       <td>128</td>
#       <td>415</td>
#       <td>382-4657</td>
#       <td>no</td>
# ...

# %%
print(df.shape)
# Out:
# (3333, 21)

# %%
print(df.columns)
# Out:
# Index(['state', 'account length', 'area code', 'phone number',
#        'international plan', 'voice mail plan', 'number vmail messages',
#        'total day minutes', 'total day calls', 'total day charge',
#        'total eve minutes', 'total eve calls', 'total eve charge',
#        'total night minutes', 'total night calls', 'total night charge',
#        'total intl minutes', 'total intl calls', 'total intl charge',
#        'customer service calls', 'churn'],
#       dtype='object')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 21 columns):
# state                     3333 non-null object
# account length            3333 non-null int64
# area code                 3333 non-null int64
# phone number              3333 non-null object
# international plan        3333 non-null object
# voice mail plan           3333 non-null object
# number vmail messages     3333 non-null int64
# total day minutes         3333 non-null float64
# total day calls           3333 non-null int64
# total day charge          3333 non-null float64
# total eve minutes         3333 non-null float64
# total eve calls           3333 non-null int64
# total eve charge          3333 non-null float64
# total night minutes       3333 non-null float64
# total night calls         3333 non-null int64
# total night charge        3333 non-null float64
# total intl minutes        3333 non-null float64
# total intl calls          3333 non-null int64
# ...

# %%
# Changing feature datatype

df['churn'] = df['churn'].astype('int64')

# %%
df.describe()
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>account length</th>
#       <th>area code</th>
#       <th>number vmail messages</th>
#       <th>total day minutes</th>
#       <th>total day calls</th>
#       <th>total day charge</th>
#       <th>total eve minutes</th>
#       <th>total eve calls</th>
#       <th>total eve charge</th>
#       <th>total night minutes</th>
#       <th>total night calls</th>
#       <th>total night charge</th>
#       <th>total intl minutes</th>
#       <th>total intl calls</th>
#       <th>total intl charge</th>
#       <th>customer service calls</th>
#       <th>churn</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>3333.000000</td>
#       <td>3333.000000</td>
#       <td>3333.000000</td>
#       <td>3333.000000</td>
#       <td>3333.000000</td>
#       <td>3333.000000</td>
#       <td>3333.000000</td>
#       <td>3333.000000</td>
# ...

# %%
# view stats on non-numeric features

df.describe(include=['object', 'bool'])
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>state</th>
#       <th>phone number</th>
#       <th>international plan</th>
#       <th>voice mail plan</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>3333</td>
#       <td>3333</td>
#       <td>3333</td>
#       <td>3333</td>
#     </tr>
#     <tr>
#       <th>unique</th>
#       <td>51</td>
#       <td>3333</td>
#       <td>2</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>top</th>
#       <td>WV</td>
#       <td>365-9371</td>
#       <td>no</td>
#       <td>no</td>
#     </tr>
#     <tr>
#       <th>freq</th>
#       <td>106</td>
#       <td>1</td>
#       <td>3010</td>
#       <td>2411</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# unique feature values

df['churn'].value_counts()
# Out:
# 0    2850
# 1     483
# Name: churn, dtype: int64

# %%
# We can view relative feature value frequencies by normalizing them into 0-1 range
df['area code'].value_counts(normalize=True)
# Out:
# 415    0.496550
# 510    0.252025
# 408    0.251425
# Name: area code, dtype: float64

# %%
# We can sort a dataframe, nice

df.sort_values(by='total day charge', 
        ascending=False).head()
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>state</th>
#       <th>account length</th>
#       <th>area code</th>
#       <th>phone number</th>
#       <th>international plan</th>
#       <th>voice mail plan</th>
#       <th>number vmail messages</th>
#       <th>total day minutes</th>
#       <th>total day calls</th>
#       <th>total day charge</th>
#       <th>total eve minutes</th>
#       <th>total eve calls</th>
#       <th>total eve charge</th>
#       <th>total night minutes</th>
#       <th>total night calls</th>
#       <th>total night charge</th>
#       <th>total intl minutes</th>
#       <th>total intl calls</th>
#       <th>total intl charge</th>
#       <th>customer service calls</th>
#       <th>churn</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>365</th>
#       <td>CO</td>
#       <td>154</td>
#       <td>415</td>
#       <td>343-5709</td>
#       <td>no</td>
# ...

# %%
df.sort_values(by=['churn', 'total day charge'],
        ascending=[True, False]).head()
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>state</th>
#       <th>account length</th>
#       <th>area code</th>
#       <th>phone number</th>
#       <th>international plan</th>
#       <th>voice mail plan</th>
#       <th>number vmail messages</th>
#       <th>total day minutes</th>
#       <th>total day calls</th>
#       <th>total day charge</th>
#       <th>total eve minutes</th>
#       <th>total eve calls</th>
#       <th>total eve charge</th>
#       <th>total night minutes</th>
#       <th>total night calls</th>
#       <th>total night charge</th>
#       <th>total intl minutes</th>
#       <th>total intl calls</th>
#       <th>total intl charge</th>
#       <th>customer service calls</th>
#       <th>churn</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>688</th>
#       <td>MN</td>
#       <td>13</td>
#       <td>510</td>
#       <td>338-7120</td>
#       <td>no</td>
# ...

# %% [markdown]
# # Indexing & slicing data

# %%
# Get single feature vector
df['churn'].mean()
# Out:
# 0.14491449144914492

# %%
# Now, some logical filtering, using boolean predicates
df[df['churn'] == 1].mean()
# Out:
# account length            102.664596
# area code                 437.817805
# number vmail messages       5.115942
# total day minutes         206.914079
# total day calls           101.335404
# total day charge           35.175921
# total eve minutes         212.410145
# total eve calls           100.561077
# total eve charge           18.054969
# total night minutes       205.231677
# total night calls         100.399586
# total night charge          9.235528
# total intl minutes         10.700000
# total intl calls            4.163561
# total intl charge           2.889545
# customer service calls      2.229814
# churn                       1.000000
# dtype: float64

# %%
# Let's combine stuff above to answer this question:
# On average, how many minutes per day do churned users speak?

df[df["churn"] == 1]["total day minutes"].mean()
# Out:
# 206.91407867494823

# %%
# What's the max international call length for loyal users that don't use roaming
df[(df['churn'] == 0) & (df['international plan'] == 'no')]['total intl minutes'].max()
# Out:
# 18.899999999999999

# %%
# Датафреймы можно индексировать как по названию столбца или строки,
# так и по порядковому номеру.
# Для индексации по названию используется метод loc, по номеру — iloc.

# %%
# передай нам значения первых пяти строк в столбцах от State до Area code

df.loc[0:5, 'state':'area code']
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>state</th>
#       <th>account length</th>
#       <th>area code</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>KS</td>
#       <td>128</td>
#       <td>415</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>OH</td>
#       <td>107</td>
#       <td>415</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>NJ</td>
#       <td>137</td>
#       <td>415</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>OH</td>
#       <td>84</td>
#       <td>408</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>OK</td>
#       <td>75</td>
#       <td>415</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>AL</td>
#       <td>118</td>
#       <td>510</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# передай нам значения первых пяти строк в первых трёх столбцах

df.iloc[0:5, 0:3]
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>state</th>
#       <th>account length</th>
#       <th>area code</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>KS</td>
#       <td>128</td>
#       <td>415</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>OH</td>
#       <td>107</td>
#       <td>415</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>NJ</td>
#       <td>137</td>
#       <td>415</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>OH</td>
#       <td>84</td>
#       <td>408</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>OK</td>
#       <td>75</td>
#       <td>415</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# # Transforming the dataset with functions

# %%
# Применение функции к каждому столбцу: apply

# Метод apply можно использовать и для того,
# чтобы применить функцию к каждой строке. 
# Для этого нужно указать axis=1.

df.apply(np.max)
# Out:
# state                           WY
# account length                 243
# area code                      510
# phone number              422-9964
# international plan             yes
# voice mail plan                yes
# number vmail messages           51
# total day minutes            350.8
# total day calls                165
# total day charge             59.64
# total eve minutes            363.7
# total eve calls                170
# total eve charge             30.91
# total night minutes            395
# total night calls              175
# total night charge           17.77
# total intl minutes              20
# total intl calls                20
# total intl charge              5.4
# customer service calls           9
# churn                            1
# dtype: object

# %%
# Применение функции к каждой ячейке столбца: map

# Например, метод map можно использовать
# для замены значений в колонке,
# передав ему в качестве аргумента 
# словарь вида {old_value: new_value}:

d = {'no': False, 'yes': True}
df['international plan'] = df['international plan'].map(d)
df.head()
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>state</th>
#       <th>account length</th>
#       <th>area code</th>
#       <th>phone number</th>
#       <th>international plan</th>
#       <th>voice mail plan</th>
#       <th>number vmail messages</th>
#       <th>total day minutes</th>
#       <th>total day calls</th>
#       <th>total day charge</th>
#       <th>total eve minutes</th>
#       <th>total eve calls</th>
#       <th>total eve charge</th>
#       <th>total night minutes</th>
#       <th>total night calls</th>
#       <th>total night charge</th>
#       <th>total intl minutes</th>
#       <th>total intl calls</th>
#       <th>total intl charge</th>
#       <th>customer service calls</th>
#       <th>churn</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>KS</td>
#       <td>128</td>
#       <td>415</td>
#       <td>382-4657</td>
#       <td>NaN</td>
# ...

# %% [markdown]
# # Grouping data

# %%
# В общем случае группировка данных в Pandas выглядит следующим образом:
# df.groupby(by=grouping_columns)[columns_to_show].function()

# %%
columns_to_show = ['total day minutes', 'total eve minutes', 'total night minutes']

df.groupby(['churn'])[columns_to_show].describe(percentiles=[])
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>total day minutes</th>
#       <th>total eve minutes</th>
#       <th>total night minutes</th>
#     </tr>
#     <tr>
#       <th>churn</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="6" valign="top">0</th>
#       <th>count</th>
#       <td>2850.000000</td>
#       <td>2850.000000</td>
#       <td>2850.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>175.175754</td>
#       <td>199.043298</td>
#       <td>200.133193</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>50.181655</td>
#       <td>50.292175</td>
#       <td>51.105032</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>23.200000</td>
#     </tr>
#     <tr>
#       <th>50%</th>
# ...

# %%
df.groupby(['churn'])[columns_to_show].agg([np.mean, np.std, np.min, np.max])
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr>
#       <th></th>
#       <th colspan="4" halign="left">total day minutes</th>
#       <th colspan="4" halign="left">total eve minutes</th>
#       <th colspan="4" halign="left">total night minutes</th>
#     </tr>
#     <tr>
#       <th></th>
#       <th>mean</th>
#       <th>std</th>
#       <th>amin</th>
#       <th>amax</th>
#       <th>mean</th>
#       <th>std</th>
#       <th>amin</th>
#       <th>amax</th>
#       <th>mean</th>
#       <th>std</th>
#       <th>amin</th>
#       <th>amax</th>
#     </tr>
#     <tr>
#       <th>churn</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>175.175754</td>
#       <td>50.181655</td>
#       <td>0.0</td>
# ...

# %% [markdown]
# # Analyzing feature dependencies with crosstab

# %%
pd.crosstab(df['churn'], df['international plan'])
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# </div>

# %%
pd.crosstab(df['churn'], df['voice mail plan'], normalize=True)
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>voice mail plan</th>
#       <th>no</th>
#       <th>yes</th>
#     </tr>
#     <tr>
#       <th>churn</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.602460</td>
#       <td>0.252625</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.120912</td>
#       <td>0.024002</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
# сводные таблицы (pivot tables). 
# В Pandas за сводные таблицы отвечает метод pivot_table,
#  который принимает в качестве параметров:

# values – список переменных, по которым требуется рассчитать нужные статистики,
# index – список переменных, по которым нужно сгруппировать данные,
# aggfunc — то, что нам, собственно, 
# нужно посчитать по группам — сумму, 
# среднее, максимум, минимум или что-то ещё.

# Сгруппируем среднее число звонков по Area Code
df.pivot_table(['total day calls',
                'total eve calls', 'total night calls'],
               ['area code'], aggfunc='mean').head(10)
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>total day calls</th>
#       <th>total eve calls</th>
#       <th>total night calls</th>
#     </tr>
#     <tr>
#       <th>area code</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>408</th>
#       <td>100.496420</td>
#       <td>99.788783</td>
#       <td>99.039379</td>
#     </tr>
#     <tr>
#       <th>415</th>
#       <td>100.576435</td>
#       <td>100.503927</td>
#       <td>100.398187</td>
#     </tr>
#     <tr>
#       <th>510</th>
#       <td>100.097619</td>
#       <td>99.671429</td>
#       <td>100.601190</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# # Transforming dataframes

# %%
total_calls = df['total day calls'] + \
              df['total eve calls'] + df['total night calls'] +\
              df['total intl calls']
df.insert(loc=len(df.columns), column='total calls', value=total_calls) 
# loc - номер столбца, после которого нужно вставить данный Series
# мы указали len(df.columns), чтобы вставить его в самом конце
df.head()
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>state</th>
#       <th>account length</th>
#       <th>area code</th>
#       <th>phone number</th>
#       <th>international plan</th>
#       <th>voice mail plan</th>
#       <th>number vmail messages</th>
#       <th>total day minutes</th>
#       <th>total day calls</th>
#       <th>total day charge</th>
#       <th>total eve minutes</th>
#       <th>total eve calls</th>
#       <th>total eve charge</th>
#       <th>total night minutes</th>
#       <th>total night calls</th>
#       <th>total night charge</th>
#       <th>total intl minutes</th>
#       <th>total intl calls</th>
#       <th>total intl charge</th>
#       <th>customer service calls</th>
#       <th>churn</th>
#       <th>Total calls</th>
#       <th>total charge</th>
#       <th>total calls</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>KS</td>
# ...

# %%
# Добавить столбец из имеющихся можно и проще, не создавая промежуточных Series:

df['total charge'] = df['total day charge'] +\
                     df['total eve charge'] + df['total night charge'] + df['total intl charge']

df.head()
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>state</th>
#       <th>account length</th>
#       <th>area code</th>
#       <th>phone number</th>
#       <th>international plan</th>
#       <th>voice mail plan</th>
#       <th>number vmail messages</th>
#       <th>total day minutes</th>
#       <th>total day calls</th>
#       <th>total day charge</th>
#       <th>total eve minutes</th>
#       <th>total eve calls</th>
#       <th>total eve charge</th>
#       <th>total night minutes</th>
#       <th>total night calls</th>
#       <th>total night charge</th>
#       <th>total intl minutes</th>
#       <th>total intl calls</th>
#       <th>total intl charge</th>
#       <th>customer service calls</th>
#       <th>churn</th>
#       <th>Total calls</th>
#       <th>total charge</th>
#       <th>total calls</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>KS</td>
# ...

# %%
# Чтобы удалить столбцы или строки,
# воспользуйтесь методом drop, 
# передавая в качестве аргумента нужные индексы 
# и требуемое значение параметра axis
#  (1, если удаляете столбцы, и ничего или 0, если удаляете строки):

# избавляемся от созданных только что столбцов
df = df.drop(['total charge', 'total calls'], axis=1) 

df.drop([1, 2]).head() # а вот так можно удалить строчки
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>state</th>
#       <th>account length</th>
#       <th>area code</th>
#       <th>phone number</th>
#       <th>international plan</th>
#       <th>voice mail plan</th>
#       <th>number vmail messages</th>
#       <th>total day minutes</th>
#       <th>total day calls</th>
#       <th>total day charge</th>
#       <th>total eve minutes</th>
#       <th>total eve calls</th>
#       <th>total eve charge</th>
#       <th>total night minutes</th>
#       <th>total night calls</th>
#       <th>total night charge</th>
#       <th>total intl minutes</th>
#       <th>total intl calls</th>
#       <th>total intl charge</th>
#       <th>customer service calls</th>
#       <th>churn</th>
#       <th>Total calls</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>KS</td>
#       <td>128</td>
#       <td>415</td>
#       <td>382-4657</td>
# ...

# %%
pd.crosstab(df['churn'], df['customer service calls'], margins=True)
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>customer service calls</th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>7</th>
#       <th>8</th>
#       <th>9</th>
#       <th>All</th>
#     </tr>
#     <tr>
#       <th>churn</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>605</td>
#       <td>1059</td>
#       <td>672</td>
#       <td>385</td>
#       <td>90</td>
#       <td>26</td>
#       <td>8</td>
#       <td>4</td>
#       <td>1</td>
#       <td>0</td>
#       <td>2850</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>92</td>
#       <td>122</td>
#       <td>87</td>
# ...

# %%
df['many_service_calls'] = (df['customer service calls'] > 3).astype('int')

pd.crosstab(df['many_service_calls'], df['churn'], margins=True)
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>churn</th>
#       <th>0</th>
#       <th>1</th>
#       <th>All</th>
#     </tr>
#     <tr>
#       <th>many_service_calls</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2721</td>
#       <td>345</td>
#       <td>3066</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>129</td>
#       <td>138</td>
#       <td>267</td>
#     </tr>
#     <tr>
#       <th>All</th>
#       <td>2850</td>
#       <td>483</td>
#       <td>3333</td>
#     </tr>
#   </tbody>
# </table>
# </div>
